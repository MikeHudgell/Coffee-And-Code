# %%
import os
import re

# %%
data_dir  = '/home/ds/data/np-text'
np_path = os.path.join(data_dir, 'NP58B.txt')

# %%
doc = open(np_path).read()

# %%
words = open(np_path, "r").read().split()    #read the words into a list.
uniqWords = sorted(set(words))               #remove duplicate words and sort
for word in uniqWords:
    print(words.count(word), word)
# Out:
# 4 &
# 1 (
# 1 (+0055
# 1 (-0515
# 2 (000?-005?5?)
# 1 (000?5?-002?5?),
# 1 (002?-007?),
# 1 (002?-010?)
# 1 (002?-012?),
# 1 (002?5?-005?5?),
# 1 (006?3?-024?7?),
# 1 (007?)
# 1 (007?-069?)
# 1 (008-026?)
# 1 (008?-022?),
# 1 (008?-344?),
# 1 (008?4?-010?7?)
# 1 (009?-011?5?),
# 1 (009?-017?5?)
# 1 (009?-017?5?),
# 1 (010?-028?)
# 1 (010?5?-021?5?),
# 1 (011?-023?5?),
# 1 (011?6?-016?7?)
# 1 (012?-018?),
# 1 (012?-018?5?),
# 1 (014?-085?)
# 1 (016?-020?)
# 1 (017?-024?5?)
# 1 (017?1?-018?9?)
# 1 (018¬?-034¬?),
# 1 (020?-030?),
# 1 (020?-031?),
# 1 (020?-033?5?)
# 1 (021?-035?5?)
# 1 (021?-037?),
# 2 (021?8?-047?8?)
# 1 (024?-027?),
# 1 (024?5?-028?),
# 4 (025?7-027?9?)
# 1 (026?-029?),
# 1 (027?-034?),
# 1 (027?7?-040?9?),
# 1 (027«?),
# 1 (028?-032?5?),
# 1 (028?5?-035?5?)
# 1 (029?)
# 2 (029?-037?)
# 1 (029?-037?),
# 1 (029?4?-060?3?)
# 1 (030?-035?),
# 1 (030?2?)
# 1 (030?5?)
# 1 (031?-041?),
# 1 (032?-034?5?),
# 1 (034?-041?)
# 1 (034?-041?),
# 1 (034?-046?)
# 3 (034?8?-054?5?)
# ...
